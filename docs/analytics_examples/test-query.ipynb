# %%
import geopandas as gpd
import os
import pandas as pd
import shapely

os.environ["CALITP_BQ_MAX_BYTES"] = str(50_000_000_000)

import calitp
from calitp.tables import tbl
from siuba import *

## Get trips for operator for one day and join with stop times for all trips
SELECTED_DATE = "2021-09-01"
ITP_ID = 278

# %%
lossan_counties = ["Los Angeles", "Orange"]

info_cols = ['itp_id', 'transit_provider', 'ntd_id',
             'modes', 'county', 'legacy_ntd_id']

vehicle_cols = ['bus', 'articulated_bus', 'over_the_road_bus',
                'school_bus', 'trolleybus', 'vintage_historic_trolley',
                'streetcar']


lossan_county_stops = (tbl.views.transitstacks()
                       >> filter(_.county.isin(lossan_counties))
                       >> select(*(info_cols + vehicle_cols))
                       >> collect()
                      )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_399/2189306493.py in <module>
#       9
#      10
# ---> 11 lossan_county_stops = (tbl.views.transitstacks()
#      12                        >> filter(_.county.isin(lossan_counties))
#      13                        >> select(*(info_cols + vehicle_cols))
#
# /opt/conda/lib/python3.9/site-packages/siuba/dply/verbs.py in __rrshift__(self, x)
#      97             return Pipeable(calls = [x] + self.calls)
#      98
# ---> 99         return self(x)
#     100
#     101     def __call__(self, x):
#
# /opt/conda/lib/python3.9/site-packages/siuba/dply/verbs.py in __call__(self, x)
#     102         res = x
#     103         for f in self.calls:
# --> 104             res = f(res)
#     105         return res
#     106
#
# /opt/conda/lib/python3.9/site-packages/siuba/siu.py in __call__(self, x)
#     201             return operator.getitem(inst, *rest)
#     202         elif self.func == "__call__":
# --> 203             return getattr(inst, self.func)(*rest, **kwargs)
#     204
#     205         # in normal case, get method to call, and then call it
#
# /opt/conda/lib/python3.9/site-packages/siuba/dply/verbs.py in wrapper(*args, **kwargs)
#     201             return dispatch_func(NoArgs(), **strip_kwargs)
#     202
# --> 203         return dispatch_func(*strip_args, **strip_kwargs)
#     204
#     205     return wrapper
#
# /opt/conda/lib/python3.9/functools.py in wrapper(*args, **kw)
#     875                             '1 positional argument')
#     876
# --> 877         return dispatch(args[0].__class__)(*args, **kw)
#     878
#     879     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /opt/conda/lib/python3.9/site-packages/siuba/sql/verbs.py in _collect(__data, as_df)
#     450             sql_db = _FixedSqlDatabase(conn)
#     451
# --> 452             return sql_db.read_sql(__data.last_op)
#     453
#     454         return conn.execute(__data.last_op)
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1577         args = _convert_params(sql, params)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#    1581
#
# /opt/conda/lib/python3.9/site-packages/siuba/sql/utils.py in execute(self, *args, **kwargs)
#      50 class _FixedSqlDatabase(_pd_sql.SQLDatabase):
#      51     def execute(self, *args, **kwargs):
# ---> 52         return self.connectable.execute(*args, **kwargs)
#      53
#      54
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1287             )
#    1288         else:
# -> 1289             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1290
#    1291     def _execute_function(self, func, multiparams, params, execution_options):
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     323     ):
#     324         if _force or self.supports_execution:
# --> 325             return connection._execute_clauseelement(
#     326                 self, multiparams, params, execution_options
#     327             )
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1471         )
#    1472
# -> 1473         compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1474             dialect=dialect,
#    1475             compiled_cache=compiled_cache,
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/elements.py in _compile_w_cache(self, dialect, compiled_cache, column_keys, for_executemany, schema_translate_map, **kw)
#     531         else:
#     532             extracted_params = None
# --> 533             compiled_sql = self._compiler(
#     534                 dialect,
#     535                 cache_key=elem_cache_key,
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/elements.py in _compiler(self, dialect, **kw)
#     553         Dialect."""
#     554
# --> 555         return dialect.statement_compiler(dialect, self, **kw)
#     556
#     557     def __str__(self):
#
# /opt/conda/lib/python3.9/site-packages/pybigquery/sqlalchemy_bigquery.py in __init__(self, dialect, statement, *args, **kwargs)
#     220         if isinstance(statement, Column):
#     221             kwargs["compile_kwargs"] = util.immutabledict({"include_table": False})
# --> 222         super(BigQueryCompiler, self).__init__(dialect, statement, *args, **kwargs)
#     223
#     224     def visit_insert(self, insert_stmt, asfrom=False, **kw):
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/compiler.py in __init__(self, dialect, statement, cache_key, column_keys, for_executemany, linting, **kwargs)
#     774         self.truncated_names = {}
#     775
# --> 776         Compiled.__init__(self, dialect, statement, **kwargs)
#     777
#     778         if self.isinsert or self.isupdate or self.isdelete:
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/compiler.py in __init__(self, dialect, statement, schema_translate_map, render_schema_translate, compile_kwargs)
#     449             if self.can_execute:
#     450                 self.execution_options = statement._execution_options
# --> 451             self.string = self.process(self.statement, **compile_kwargs)
#     452
#     453             if render_schema_translate:
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/compiler.py in process(self, obj, **kwargs)
#     484
#     485     def process(self, obj, **kwargs):
# --> 486         return obj._compiler_dispatch(self, **kwargs)
#     487
#     488     def __str__(self):
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/visitors.py in _compiler_dispatch(self, visitor, **kw)
#      80
#      81         else:
# ---> 82             return meth(self, **kw)
#      83
#      84     cls._compiler_dispatch = (
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/compiler.py in visit_select(self, select_stmt, asfrom, insert_into, fromhints, compound_index, select_wraps_for, lateral, from_linter, **kwargs)
#    3361             ]
#    3362
# -> 3363         text = self._compose_select_body(
#    3364             text,
#    3365             select_stmt,
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/compiler.py in _compose_select_body(self, text, select, compile_state, inner_columns, froms, byfrom, toplevel, kwargs)
#    3519
#    3520         if select._where_criteria:
# -> 3521             t = self._generate_delimited_and_list(
#    3522                 select._where_criteria, from_linter=from_linter, **kwargs
#    3523             )
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/compiler.py in _generate_delimited_and_list(self, clauses, **kw)
#    1660         )
#    1661         if lcc == 1:
# -> 1662             return clauses[0]._compiler_dispatch(self, **kw)
#    1663         else:
#    1664             separator = OPERATORS[operators.and_]
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/visitors.py in _compiler_dispatch(self, visitor, **kw)
#      80
#      81         else:
# ---> 82             return meth(self, **kw)
#      83
#      84     cls._compiler_dispatch = (
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/compiler.py in visit_binary(self, binary, override_operator, eager_grouping, from_linter, lateral_from_linter, **kw)
#    2150         disp = self._get_operator_dispatch(operator_, "binary", None)
#    2151         if disp:
# -> 2152             return disp(binary, operator_, **kw)
#    2153         else:
#    2154             try:
#
# /opt/conda/lib/python3.9/site-packages/pybigquery/sqlalchemy_bigquery.py in visit_in_op_binary(self, binary, operator_, **kw)
#     311     def visit_in_op_binary(self, binary, operator_, **kw):
#     312         return self.__in_expanding_bind(
# --> 313             self._generate_generic_binary(binary, " IN ", **kw)
#     314         )
#     315
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/compiler.py in _generate_generic_binary(self, binary, opstring, eager_grouping, **kw)
#    2216             )
#    2217             + opstring
# -> 2218             + binary.right._compiler_dispatch(
#    2219                 self, eager_grouping=eager_grouping, **kw
#    2220             )
#
# /opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/visitors.py in _compiler_dispatch(self, visitor, **kw)
#      80
#      81         else:
# ---> 82             return meth(self, **kw)
#      83
#      84     cls._compiler_dispatch = (
#
# /opt/conda/lib/python3.9/site-packages/pybigquery/sqlalchemy_bigquery.py in visit_bindparam(self, bindparam, within_columns_clause, literal_binds, skip_bind_expression, **kwargs)
#     435
#     436         if bindparam.expanding:
# --> 437             assert_(self.__expanded_param(param), f"Unexpected param: {param}")
#     438             param = param.replace(")", f":{bq_type})")
#     439
#
# /opt/conda/lib/python3.9/site-packages/pybigquery/sqlalchemy_bigquery.py in assert_(cond, message)
#      61 def assert_(cond, message="Assertion failed"):  # pragma: NO COVER
#      62     if not cond:
# ---> 63         raise AssertionError(message)
#      64
#      65
#
# AssertionError: Unexpected param: (__[POSTCOMPILE_county_1])

# %%
'''
lossan_counties = ['San Luis Obispo', 'Santa Barbara', 'Ventura',
                  'Los Angeles', 'San Diego', 'Orange']

one_county = ["Los Angeles"]
info_cols = ['itp_id', 'transit_provider', 'ntd_id',
             'modes', 'county', 'legacy_ntd_id']

vehicle_cols = ['bus', 'articulated_bus', 'over_the_road_bus',
                'school_bus', 'trolleybus', 'vintage_historic_trolley',
                'streetcar']

paratransit_cols = ['van', 'cutaway', 'automobile', 
                    'minivan', 'sport_utility_vehicle']

lossan_operators = (tbl.views.transitstacks()
                    >> filter(_.county.isin(lossan_counties))
                    #>> select(*(info_cols + vehicle_cols + paratransit_cols))
                    >> collect()
                    )
'''
